# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
ds=pd.read_csv("Toyota.csv")

# %%
ds.plot.scatter(x='Age',y='Price')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Price'>

# %%
ds['KM'].plot(kind= 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
ds['CC'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
ds['FuelType'].value_counts().plot(kind= 'bar')
# Out:
# <AxesSubplot:>
